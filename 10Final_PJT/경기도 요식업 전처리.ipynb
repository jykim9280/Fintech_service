# %%
import pandas as pd
import numpy as np
import json

# %%
data = pd.read_json("./new_data_columns.json")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 167161 entries, 0 to 167160
# Data columns (total 22 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   상가업소번호     167161 non-null  object
#  1   상호명        167161 non-null  object
#  2   지점명        9032 non-null    object
#  3   상권업종대분류코드  167161 non-null  object
#  4   상권업종대분류명   167161 non-null  object
#  5   상권업종중분류코드  167161 non-null  object
#  6   상권업종중분류명   167161 non-null  object
#  7   상권업종소분류코드  167161 non-null  object
#  8   상권업종소분류명   167161 non-null  object
#  9   표준산업분류코드   167099 non-null  object
#  10  표준산업분류명    167099 non-null  object
#  11  시도코드       167161 non-null  int64
#  12  시도명        167161 non-null  object
#  13  시군구코드      167161 non-null  int64
#  14  시군구명       167161 non-null  object
#  15  행정동코드      167161 non-null  int64
#  16  행정동명       167161 non-null  object
#  17  도로명코드      167067 non-null  float64
#  18  도로명        167161 non-null  object
# ...

# %%
data[data['도로명코드'].isna() == True].head(20)
# Out:
#                      상가업소번호           상호명   지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드  \
# 457    MA010120220805480062       레드인거북섬점  None        I2       음식      I210
# 732    MA010120220805496321    랑데자뷰시흥거북섬점  None        I2       음식      I212
# 1506   MA010120220805687282        고기장인백정  None        I2       음식      I201
# 5889   MA010120220806579531           골목집  None        I2       음식      I201
# 8048   MA010120220806792250        박군치킨동탄  None        I2       음식      I210
# 8601   MA010120220806838388        후르츠바스켓  None        I2       음식      I212
# 8929   MA010120220806854033      고래맥주창고동탄  None        I2       음식      I211
# 11255  MA010120220807107688       오다가다샤슬릭  None        I2       음식      I201
# 13042  MA010120220807397125           우리집  None        I2       음식      I201
# 13294  MA010120220807492471        더벤티초롱꽃  None        I2       음식      I212
# 16583  MA010120220808195974  메가커피시흥웨이브파크점  None        I2       음식      I212
# ...

# %%
data.head()
# Out:
#                  상가업소번호         상호명   지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드  \
# 0  MA0101202210A0071854          희야  None        I2       음식      I203
# 1  MA0101202210A0076234  비에이치씨충호회관점  None        I2       음식      I210
# 2  MA0101202210A0058768     생곡메밀막국수  None        I2       음식      I201
# 3  MA010120220805430777        고매커피  None        I2       음식      I212
# 4  MA010120220805430792     푸라닭성남동점  None        I2       음식      I210
#
#   상권업종중분류명 상권업종소분류코드 상권업종소분류명 표준산업분류코드  ...  시도명  시군구코드     시군구명     행정동코드  \
# 0       일식    I20301  일식 회/초밥   I56122  ...  경기도  41220      평택시  41220520
# 1    기타 간이    I21006       치킨   I56193  ...  경기도  41360     남양주시  41360250
# 2       한식    I20105   국수/칼국수   I56112  ...  경기도  41590      화성시  41590540
# 3    비알코올     I21201       카페   I56221  ...  경기도  41463  용인시 기흥구  41463540
# 4    기타 간이    I21006       치킨   I56193  ...  경기도  41133  성남시 중원구  41133510
#
#    행정동명         도로명코드                    도로명                        도로명주소  \
# ...
