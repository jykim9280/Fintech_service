# %% [markdown]
# # 전국 아파트 매매 데이터 1999-2024 합치기

# %%
import pandas as pd
import glob

# 각 월별 파일 경로 불러오기
all_files = []

for i in range(1, 10):
    output1 = glob.glob(f'data/*0{i}.csv')
    all_files.extend(output1)  # 모든 파일 경로를 리스트에 추가

# 파일을 읽어서 데이터프레임으로 저장 (sep=None로 구분자 자동 감지)
data_frames = [pd.read_csv(file,encoding='cp949', skiprows=15) for file in all_files]

# 하나의 데이터프레임으로 합치기
combined_df = pd.concat(data_frames, ignore_index=True)

# 데이터 확인
print(combined_df.head())
# Out:
# C:\Users\5-12\AppData\Local\Temp\ipykernel_13224\1944289335.py:12: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_frames = [pd.read_csv(file,encoding='cp949', skiprows=15) for file in all_files]
# C:\Users\5-12\AppData\Local\Temp\ipykernel_13224\1944289335.py:12: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_frames = [pd.read_csv(file,encoding='cp949', skiprows=15) for file in all_files]
# C:\Users\5-12\AppData\Local\Temp\ipykernel_13224\1944289335.py:12: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_frames = [pd.read_csv(file,encoding='cp949', skiprows=15) for file in all_files]
# C:\Users\5-12\AppData\Local\Temp\ipykernel_13224\1944289335.py:12: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_frames = [pd.read_csv(file,encoding='cp949', skiprows=15) for file in all_files]
# C:\Users\5-12\AppData\Local\Temp\ipykernel_13224\1944289335.py:12: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_frames = [pd.read_csv(file,encoding='cp949', skiprows=15) for file in all_files]
# C:\Users\5-12\AppData\Local\Temp\ipykernel_13224\1944289335.py:12: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_frames = [pd.read_csv(file,encoding='cp949', skiprows=15) for file in all_files]
# C:\Users\5-12\AppData\Local\Temp\ipykernel_13224\1944289335.py:12: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_frames = [pd.read_csv(file,encoding='cp949', skiprows=15) for file in all_files]
# C:\Users\5-12\AppData\Local\Temp\ipykernel_13224\1944289335.py:12: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_frames = [pd.read_csv(file,encoding='cp949', skiprows=15) for file in all_files]
# C:\Users\5-12\AppData\Local\Temp\ipykernel_13224\1944289335.py:12: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_frames = [pd.read_csv(file,encoding='cp949', skiprows=15) for file in all_files]
# C:\Users\5-12\AppData\Local\Temp\ipykernel_13224\1944289335.py:12: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_frames = [pd.read_csv(file,encoding='cp949', skiprows=15) for file in all_files]
# C:\Users\5-12\AppData\Local\Temp\ipykernel_13224\1944289335.py:12: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_frames = [pd.read_csv(file,encoding='cp949', skiprows=15) for file in all_files]
# C:\Users\5-12\AppData\Local\Temp\ipykernel_13224\1944289335.py:12: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_frames = [pd.read_csv(file,encoding='cp949', skiprows=15) for file in all_files]
# C:\Users\5-12\AppData\Local\Temp\ipykernel_13224\1944289335.py:12: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_frames = [pd.read_csv(file,encoding='cp949', skiprows=15) for file in all_files]
# C:\Users\5-12\AppData\Local\Temp\ipykernel_13224\1944289335.py:12: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_frames = [pd.read_csv(file,encoding='cp949', skiprows=15) for file in all_files]
# C:\Users\5-12\AppData\Local\Temp\ipykernel_13224\1944289335.py:12: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_frames = [pd.read_csv(file,encoding='cp949', skiprows=15) for file in all_files]
# C:\Users\5-12\AppData\Local\Temp\ipykernel_13224\1944289335.py:12: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_frames = [pd.read_csv(file,encoding='cp949', skiprows=15) for file in all_files]
# C:\Users\5-12\AppData\Local\Temp\ipykernel_13224\1944289335.py:12: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_frames = [pd.read_csv(file,encoding='cp949', skiprows=15) for file in all_files]
# C:\Users\5-12\AppData\Local\Temp\ipykernel_13224\1944289335.py:12: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_frames = [pd.read_csv(file,encoding='cp949', skiprows=15) for file in all_files]
# C:\Users\5-12\AppData\Local\Temp\ipykernel_13224\1944289335.py:12: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_frames = [pd.read_csv(file,encoding='cp949', skiprows=15) for file in all_files]
# C:\Users\5-12\AppData\Local\Temp\ipykernel_13224\1944289335.py:12: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_frames = [pd.read_csv(file,encoding='cp949', skiprows=15) for file in all_files]
# C:\Users\5-12\AppData\Local\Temp\ipykernel_13224\1944289335.py:12: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_frames = [pd.read_csv(file,encoding='cp949', skiprows=15) for file in all_files]
# C:\Users\5-12\AppData\Local\Temp\ipykernel_13224\1944289335.py:12: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_frames = [pd.read_csv(file,encoding='cp949', skiprows=15) for file in all_files]
# C:\Users\5-12\AppData\Local\Temp\ipykernel_13224\1944289335.py:12: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_frames = [pd.read_csv(file,encoding='cp949', skiprows=15) for file in all_files]
# C:\Users\5-12\AppData\Local\Temp\ipykernel_13224\1944289335.py:12: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_frames = [pd.read_csv(file,encoding='cp949', skiprows=15) for file in all_files]
# C:\Users\5-12\AppData\Local\Temp\ipykernel_13224\1944289335.py:12: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_frames = [pd.read_csv(file,encoding='cp949', skiprows=15) for file in all_files]
# C:\Users\5-12\AppData\Local\Temp\ipykernel_13224\1944289335.py:12: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_frames = [pd.read_csv(file,encoding='cp949', skiprows=15) for file in all_files]
# C:\Users\5-12\AppData\Local\Temp\ipykernel_13224\1944289335.py:12: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_frames = [pd.read_csv(file,encoding='cp949', skiprows=15) for file in all_files]
# C:\Users\5-12\AppData\Local\Temp\ipykernel_13224\1944289335.py:12: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_frames = [pd.read_csv(file,encoding='cp949', skiprows=15) for file in all_files]
# C:\Users\5-12\AppData\Local\Temp\ipykernel_13224\1944289335.py:12: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_frames = [pd.read_csv(file,encoding='cp949', skiprows=15) for file in all_files]
# C:\Users\5-12\AppData\Local\Temp\ipykernel_13224\1944289335.py:12: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_frames = [pd.read_csv(file,encoding='cp949', skiprows=15) for file in all_files]
# C:\Users\5-12\AppData\Local\Temp\ipykernel_13224\1944289335.py:12: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_frames = [pd.read_csv(file,encoding='cp949', skiprows=15) for file in all_files]
# C:\Users\5-12\AppData\Local\Temp\ipykernel_13224\1944289335.py:12: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_frames = [pd.read_csv(file,encoding='cp949', skiprows=15) for file in all_files]
# C:\Users\5-12\AppData\Local\Temp\ipykernel_13224\1944289335.py:12: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_frames = [pd.read_csv(file,encoding='cp949', skiprows=15) for file in all_files]
# C:\Users\5-12\AppData\Local\Temp\ipykernel_13224\1944289335.py:12: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_frames = [pd.read_csv(file,encoding='cp949', skiprows=15) for file in all_files]
# C:\Users\5-12\AppData\Local\Temp\ipykernel_13224\1944289335.py:12: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_frames = [pd.read_csv(file,encoding='cp949', skiprows=15) for file in all_files]
# C:\Users\5-12\AppData\Local\Temp\ipykernel_13224\1944289335.py:12: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_frames = [pd.read_csv(file,encoding='cp949', skiprows=15) for file in all_files]
# C:\Users\5-12\AppData\Local\Temp\ipykernel_13224\1944289335.py:12: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_frames = [pd.read_csv(file,encoding='cp949', skiprows=15) for file in all_files]
# C:\Users\5-12\AppData\Local\Temp\ipykernel_13224\1944289335.py:15: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   combined_df = pd.concat(data_frames, ignore_index=True)
#                시군구   번지   본번   부번   단지명  전용면적(㎡)    계약년월 계약일 거래금액(만원)   층  \
# 0  강원특별자치도 강릉시 견소동  202  202  0.0  송정한신   84.945  200701   4    8,000  15
# 1  강원특별자치도 강릉시 견소동  202  202  0.0  송정한신   84.930  200701   8    8,100   7
# 2  강원특별자치도 강릉시 견소동  202  202  0.0  송정한신   84.945  200701   8    8,200  14
# 3  강원특별자치도 강릉시 견소동  202  202  0.0  송정한신   84.945  200701  25    7,900  15
# 4  강원특별자치도 강릉시 견소동  202  202  0.0  송정한신   84.930  200701  31    6,000   4
#
#    ...          도로명 해제사유발생일 등기신청일자 거래유형 중개사소재지  NO    동  매수자  매도자 등기일자
# 0  ...  경강로2539번길 8     NaN           -      - NaN  NaN  NaN  NaN  NaN
# 1  ...  경강로2539번길 8     NaN           -      - NaN  NaN  NaN  NaN  NaN
# 2  ...  경강로2539번길 8     NaN           -      - NaN  NaN  NaN  NaN  NaN
# 3  ...  경강로2539번길 8     NaN           -      - NaN  NaN  NaN  NaN  NaN
# 4  ...  경강로2539번길 8     NaN           -      - NaN  NaN  NaN  NaN  NaN
#
# [5 rows x 21 columns]

# %%
import pandas as pd
import glob

# 각 월별 파일 경로 불러오기
all_files2 = []

for i in range(10, 13):
    output2 = glob.glob(f'data/*{i}.csv')
    all_files2.extend(output2)  # 모든 파일 경로를 리스트에 추가

# 파일을 읽어서 데이터프레임으로 저장 (sep=None로 구분자 자동 감지)
data_frames2 = [pd.read_csv(file,encoding='cp949', skiprows=15) for file in all_files2]

# 하나의 데이터프레임으로 합치기
combined_df2 = pd.concat(data_frames2, ignore_index=True)

# 데이터 확인
print(combined_df2.head())
# Out:
# C:\Users\5-12\AppData\Local\Temp\ipykernel_13224\225239017.py:12: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_frames2 = [pd.read_csv(file,encoding='cp949', skiprows=15) for file in all_files2]
# C:\Users\5-12\AppData\Local\Temp\ipykernel_13224\225239017.py:12: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_frames2 = [pd.read_csv(file,encoding='cp949', skiprows=15) for file in all_files2]
# C:\Users\5-12\AppData\Local\Temp\ipykernel_13224\225239017.py:12: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_frames2 = [pd.read_csv(file,encoding='cp949', skiprows=15) for file in all_files2]
# C:\Users\5-12\AppData\Local\Temp\ipykernel_13224\225239017.py:12: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_frames2 = [pd.read_csv(file,encoding='cp949', skiprows=15) for file in all_files2]
# C:\Users\5-12\AppData\Local\Temp\ipykernel_13224\225239017.py:12: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_frames2 = [pd.read_csv(file,encoding='cp949', skiprows=15) for file in all_files2]
# C:\Users\5-12\AppData\Local\Temp\ipykernel_13224\225239017.py:12: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_frames2 = [pd.read_csv(file,encoding='cp949', skiprows=15) for file in all_files2]
# C:\Users\5-12\AppData\Local\Temp\ipykernel_13224\225239017.py:12: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_frames2 = [pd.read_csv(file,encoding='cp949', skiprows=15) for file in all_files2]
# C:\Users\5-12\AppData\Local\Temp\ipykernel_13224\225239017.py:12: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_frames2 = [pd.read_csv(file,encoding='cp949', skiprows=15) for file in all_files2]
# C:\Users\5-12\AppData\Local\Temp\ipykernel_13224\225239017.py:12: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_frames2 = [pd.read_csv(file,encoding='cp949', skiprows=15) for file in all_files2]
# C:\Users\5-12\AppData\Local\Temp\ipykernel_13224\225239017.py:12: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_frames2 = [pd.read_csv(file,encoding='cp949', skiprows=15) for file in all_files2]
# C:\Users\5-12\AppData\Local\Temp\ipykernel_13224\225239017.py:12: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_frames2 = [pd.read_csv(file,encoding='cp949', skiprows=15) for file in all_files2]
# C:\Users\5-12\AppData\Local\Temp\ipykernel_13224\225239017.py:12: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_frames2 = [pd.read_csv(file,encoding='cp949', skiprows=15) for file in all_files2]
# C:\Users\5-12\AppData\Local\Temp\ipykernel_13224\225239017.py:12: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_frames2 = [pd.read_csv(file,encoding='cp949', skiprows=15) for file in all_files2]
# C:\Users\5-12\AppData\Local\Temp\ipykernel_13224\225239017.py:15: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   combined_df2 = pd.concat(data_frames2, ignore_index=True)
#                시군구     번지   본번   부번    단지명  전용면적(㎡)    계약년월 계약일 거래금액(만원)   층  \
# 0     경기도 의정부시 민락동  756-7  756  7.0  한라비발디   84.990  200510  30   12,750  19
# 1     경기도 의정부시 신곡동    456  456  0.0    신일1   59.878  200510  20    5,750   3
# 2     경기도 의정부시 신곡동  727-1  727  1.0     풍림   49.830  200510  20    5,500   8
# 3  강원특별자치도 강릉시 견소동    202  202  0.0   송정한신   59.800  200610   9    5,500   4
# 4  강원특별자치도 강릉시 견소동    202  202  0.0   송정한신   43.380  200610  19    3,900   3
#
#    ...          도로명 해제사유발생일 등기신청일자 거래유형 중개사소재지  NO    동  매수자  매도자 등기일자
# 0  ...       오목로 73     NaN           -      - NaN  NaN  NaN  NaN  NaN
# 1  ...  시민로245번길 10     NaN           -      - NaN  NaN  NaN  NaN  NaN
# 2  ...      회룡로 245     NaN           -      - NaN  NaN  NaN  NaN  NaN
# 3  ...  경강로2539번길 8     NaN           -      - NaN  NaN  NaN  NaN  NaN
# 4  ...  경강로2539번길 8     NaN           -      - NaN  NaN  NaN  NaN  NaN
#
# [5 rows x 21 columns]

# %%
combined_df.head()
# Out:
#                시군구   번지   본번   부번   단지명  전용면적(㎡)    계약년월 계약일 거래금액(만원)   층  \
# 0  강원특별자치도 강릉시 견소동  202  202  0.0  송정한신   84.945  200701   4    8,000  15
# 1  강원특별자치도 강릉시 견소동  202  202  0.0  송정한신   84.930  200701   8    8,100   7
# 2  강원특별자치도 강릉시 견소동  202  202  0.0  송정한신   84.945  200701   8    8,200  14
# 3  강원특별자치도 강릉시 견소동  202  202  0.0  송정한신   84.945  200701  25    7,900  15
# 4  강원특별자치도 강릉시 견소동  202  202  0.0  송정한신   84.930  200701  31    6,000   4
#
#    ...          도로명 해제사유발생일 등기신청일자 거래유형 중개사소재지  NO    동  매수자  매도자 등기일자
# 0  ...  경강로2539번길 8     NaN           -      - NaN  NaN  NaN  NaN  NaN
# 1  ...  경강로2539번길 8     NaN           -      - NaN  NaN  NaN  NaN  NaN
# 2  ...  경강로2539번길 8     NaN           -      - NaN  NaN  NaN  NaN  NaN
# 3  ...  경강로2539번길 8     NaN           -      - NaN  NaN  NaN  NaN  NaN
# 4  ...  경강로2539번길 8     NaN           -      - NaN  NaN  NaN  NaN  NaN
#
# [5 rows x 21 columns]

# %%
combined_df2.head()
# Out:
#                시군구     번지   본번   부번    단지명  전용면적(㎡)    계약년월 계약일 거래금액(만원)   층  \
# 0     경기도 의정부시 민락동  756-7  756  7.0  한라비발디   84.990  200510  30   12,750  19
# 1     경기도 의정부시 신곡동    456  456  0.0    신일1   59.878  200510  20    5,750   3
# 2     경기도 의정부시 신곡동  727-1  727  1.0     풍림   49.830  200510  20    5,500   8
# 3  강원특별자치도 강릉시 견소동    202  202  0.0   송정한신   59.800  200610   9    5,500   4
# 4  강원특별자치도 강릉시 견소동    202  202  0.0   송정한신   43.380  200610  19    3,900   3
#
#    ...          도로명 해제사유발생일 등기신청일자 거래유형 중개사소재지  NO    동  매수자  매도자 등기일자
# 0  ...       오목로 73     NaN           -      - NaN  NaN  NaN  NaN  NaN
# 1  ...  시민로245번길 10     NaN           -      - NaN  NaN  NaN  NaN  NaN
# 2  ...      회룡로 245     NaN           -      - NaN  NaN  NaN  NaN  NaN
# 3  ...  경강로2539번길 8     NaN           -      - NaN  NaN  NaN  NaN  NaN
# 4  ...  경강로2539번길 8     NaN           -      - NaN  NaN  NaN  NaN  NaN
#
# [5 rows x 21 columns]

# %%
combined_df.columns
# Out:
# Index(['시군구', '번지', '본번', '부번', '단지명', '전용면적(㎡)', '계약년월', '계약일', '거래금액(만원)',
#        '층', '건축년도', '도로명', '해제사유발생일', '등기신청일자', '거래유형', '중개사소재지', 'NO', '동',
#        '매수자', '매도자', '등기일자'],
#       dtype='object')

# %%
import pandas as pd
import time

# 시간 기록 시작
start_time = time.time()

# 진행 상황 확인을 위한 메시지 출력
print("Concatenation started...")

# 데이터프레임 결합
apt_result = pd.concat([combined_df, combined_df2], axis=0)

# 시간 기록 종료
end_time = time.time()

# 완료 메시지 및 소요 시간 출력
print(f"Concatenation completed in {end_time - start_time:.2f} seconds.")
# Out:
# Concatenation started...
# Concatenation completed in 0.77 seconds.

# %%
apt_result.head(15)
# Out:
#                 시군구     번지    본번   부번           단지명  전용면적(㎡)    계약년월 계약일  \
# 0   강원특별자치도 강릉시 견소동    202   202  0.0          송정한신   84.945  200701   4
# 1   강원특별자치도 강릉시 견소동    202   202  0.0          송정한신   84.930  200701   8
# 2   강원특별자치도 강릉시 견소동    202   202  0.0          송정한신   84.945  200701   8
# 3   강원특별자치도 강릉시 견소동    202   202  0.0          송정한신   84.945  200701  25
# 4   강원특별자치도 강릉시 견소동    202   202  0.0          송정한신   84.930  200701  31
# 5   강원특별자치도 강릉시 견소동    289   289  0.0  송정해변신도브래뉴아파트   59.990  200701   2
# 6   강원특별자치도 강릉시 견소동    289   289  0.0  송정해변신도브래뉴아파트   84.990  200701   5
# 7   강원특별자치도 강릉시 견소동    289   289  0.0  송정해변신도브래뉴아파트   84.990  200701  14
# 8   강원특별자치도 강릉시 견소동    289   289  0.0  송정해변신도브래뉴아파트   59.990  200701  26
# 9   강원특별자치도 강릉시 견소동    289   289  0.0  송정해변신도브래뉴아파트   84.990  200701  27
# 10   강원특별자치도 강릉시 교동  797-1   797  1.0            강원   59.490  200701  11
# 11   강원특별자치도 강릉시 교동  797-1   797  1.0            강원   59.490  200701  22
# 12   강원특별자치도 강릉시 교동   1750  1750  0.0         교동1주공   84.840  200701   5
# 13   강원특별자치도 강릉시 교동   1750  1750  0.0         교동1주공   59.890  200701   6
# 14   강원특별자치도 강릉시 교동   1750  1750  0.0         교동1주공   59.890  200701   8
#
#    거래금액(만원)   층  ...           도로명 해제사유발생일 등기신청일자 거래유형 중개사소재지  NO    동  매수자  \
# 0     8,000  15  ...   경강로2539번길 8     NaN           -      - NaN  NaN  NaN
# 1     8,100   7  ...   경강로2539번길 8     NaN           -      - NaN  NaN  NaN
# 2     8,200  14  ...   경강로2539번길 8     NaN           -      - NaN  NaN  NaN
# 3     7,900  15  ...   경강로2539번길 8     NaN           -      - NaN  NaN  NaN
# 4     6,000   4  ...   경강로2539번길 8     NaN           -      - NaN  NaN  NaN
# 5     9,800  15  ...  경강로2539번길 22     NaN           -      - NaN  NaN  NaN
# 6    14,200  12  ...  경강로2539번길 22     NaN           -      - NaN  NaN  NaN
# 7    10,390   1  ...  경강로2539번길 22     NaN           -      - NaN  NaN  NaN
# 8    10,500  10  ...  경강로2539번길 23     NaN           -      - NaN  NaN  NaN
# 9    14,000   9  ...  경강로2539번길 22     NaN           -      - NaN  NaN  NaN
# 10    4,350   4  ...   화부산로131번길 6     NaN           -      - NaN  NaN  NaN
# 11    3,900   3  ...   화부산로131번길 6     NaN           -      - NaN  NaN  NaN
# 12   13,300  12  ...        가작로 78     NaN           -      - NaN  NaN  NaN
# 13    8,500   6  ...        가작로 78     NaN           -      - NaN  NaN  NaN
# 14    7,300   2  ...        가작로 78     NaN           -      - NaN  NaN  NaN
#
#     매도자 등기일자
# 0   NaN  NaN
# 1   NaN  NaN
# 2   NaN  NaN
# 3   NaN  NaN
# 4   NaN  NaN
# 5   NaN  NaN
# 6   NaN  NaN
# 7   NaN  NaN
# 8   NaN  NaN
# 9   NaN  NaN
# 10  NaN  NaN
# 11  NaN  NaN
# 12  NaN  NaN
# 13  NaN  NaN
# 14  NaN  NaN
#
# [15 rows x 21 columns]

# %%
apt_result[apt_result['계약년월'] == 200510]
# Out:
#             시군구     번지   본번   부번    단지명  전용면적(㎡)    계약년월 계약일 거래금액(만원)   층  \
# 0  경기도 의정부시 민락동  756-7  756  7.0  한라비발디   84.990  200510  30   12,750  19
# 1  경기도 의정부시 신곡동    456  456  0.0    신일1   59.878  200510  20    5,750   3
# 2  경기도 의정부시 신곡동  727-1  727  1.0     풍림   49.830  200510  20    5,500   8
#
#    ...          도로명 해제사유발생일 등기신청일자 거래유형 중개사소재지  NO    동  매수자  매도자 등기일자
# 0  ...       오목로 73     NaN           -      - NaN  NaN  NaN  NaN  NaN
# 1  ...  시민로245번길 10     NaN           -      - NaN  NaN  NaN  NaN  NaN
# 2  ...      회룡로 245     NaN           -      - NaN  NaN  NaN  NaN  NaN
#
# [3 rows x 21 columns]

# %%
apt_result.columns
# Out:
# Index(['시군구', '번지', '본번', '부번', '단지명', '전용면적(㎡)', '계약년월', '계약일', '거래금액(만원)',
#        '층', '건축년도', '도로명', '해제사유발생일', '등기신청일자', '거래유형', '중개사소재지', 'NO', '동',
#        '매수자', '매도자', '등기일자'],
#       dtype='object')

# %%
apt_result['건축년도']
# Out:
# 0          1997.0
# 1          1997.0
# 2          1997.0
# 3          1997.0
# 4          1997.0
#             ...
# 2399984    2010.0
# 2399985    1997.0
# 2399986    2014.0
# 2399987    2020.0
# 2399988    2005.0
# Name: 건축년도, Length: 10041451, dtype: float64

# %%
apt_data = apt_result.copy()
# 완료된 데이터 apt_result

# %%
# import pandas as pd

# # 16번째 줄부터 데이터를 불러오기
# data = pd.read_csv("./data/200510.csv", encoding='cp949', skiprows=15)

# # 데이터 확인
# data.head(20)
# Out:
#             시군구     번지   본번  부번    단지명  전용면적(㎡)    계약년월  계약일 거래금액(만원)   층  \
# 0  경기도 의정부시 민락동  756-7  756   7  한라비발디   84.990  200510   30   12,750  19
# 1  경기도 의정부시 신곡동    456  456   0    신일1   59.878  200510   20    5,750   3
# 2  경기도 의정부시 신곡동  727-1  727   1     풍림   49.830  200510   20    5,500   8
#
#    건축년도          도로명  해제사유발생일 등기신청일자 거래유형 중개사소재지
# 0  2003       오목로 73      NaN           -      -
# 1  1997  시민로245번길 10      NaN           -      -
# 2  1998      회룡로 245      NaN           -      -

# %% [markdown]
# # database에서 1999-2024 USD 환율정보 가져와서 합치기
# - 날짜와 USD 살때 데이터만 사용
# - 토,일 공휴일 데이터는 그 전날 데이터로 맵핑

# %%
# !pip install pandas sqlalchemy pymysql
# Out:
# Requirement already satisfied: pandas in c:\users\5-12\miniforge3\envs\fintech\lib\site-packages (2.2.2)
# Requirement already satisfied: sqlalchemy in c:\users\5-12\miniforge3\envs\fintech\lib\site-packages (2.0.31)
# Requirement already satisfied: pymysql in c:\users\5-12\miniforge3\envs\fintech\lib\site-packages (1.1.0)
# Requirement already satisfied: numpy>=1.22.4 in c:\users\5-12\miniforge3\envs\fintech\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\5-12\miniforge3\envs\fintech\lib\site-packages (from pandas) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\5-12\miniforge3\envs\fintech\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\5-12\miniforge3\envs\fintech\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\5-12\miniforge3\envs\fintech\lib\site-packages (from sqlalchemy) (4.12.2)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\5-12\miniforge3\envs\fintech\lib\site-packages (from sqlalchemy) (3.0.3)
# Requirement already satisfied: six>=1.5 in c:\users\5-12\miniforge3\envs\fintech\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
import pandas as pd
from sqlalchemy import create_engine

# MySQL 연결 설정 (자신의 정보로 수정)
username = 'root'  # MySQL 사용자 이름
password = '1234'  # MySQL 비밀번호
host = 'localhost'  # 로컬 호스트
port = 3306  # MySQL 기본 포트
database = 'korea_exchange_rate'  # 데이터베이스 이름

# SQLAlchemy 엔진 생성
engine = create_engine(f'mysql+pymysql://{username}:{password}@{host}:{port}/{database}')

# SQL 쿼리를 통해 데이터를 불러오기
query = "SELECT * FROM exchange_rate;"  # 'exchange_rate' 테이블의 모든 데이터 가져오기
ex_result = pd.read_sql(query, engine)

# 데이터 확인
print(ex_data.head())
# Out:
#          date            통화  현찰_살때_환율  현찰_살때_Spread  현찰_팔때_환율
# 383520  1349.0  1323.0     NaN   1320.52  1336.0  6.70478     1.0
# 383578  1343.8  1317.8     NaN   1315.33  1330.8  6.70447     1.0

# %%
# '날짜'와 '현찰_살때_환율' 컬럼만 선택
selected_data = ex_result[['date', '현찰_살때_환율']]
selected_data = selected_data.rename(columns={'date':'날짜', '현찰_살때_환율': 'USD_살때_환율'})
selected_data = selected_data.reset_index(drop=True)

# 결과 확인
selected_data.head(30)
# Out:
#             날짜  USD_살때_환율
# 0   1995-01-03     800.53
# 1   1995-01-04     800.33
# 2   1995-01-05     801.14
# 3   1995-01-06     801.44
# 4   1995-01-09     802.15
# 5   1995-01-10     802.87
# 6   1995-01-11     803.07
# 7   1995-01-12     802.05
# 8   1995-01-13     801.85
# 9   1995-01-16     804.69
# 10  1995-01-17     804.59
# 11  1995-01-18     803.88
# 12  1995-01-19     804.39
# 13  1995-01-20     804.29
# 14  1995-01-23     804.39
# 15  1995-01-24     804.18
# 16  1995-01-25     801.95
# 17  1995-01-26     799.21
# 18  1995-01-27     797.08
# 19  1995-01-30     797.08
# 20  1995-01-31     797.08
# 21  1995-02-01     797.08
# 22  1995-02-02     798.50
# 23  1995-02-03     800.73
# 24  1995-02-06     803.47
# 25  1995-02-07     803.98
# 26  1995-02-08     801.75
# 27  1995-02-09     802.15
# 28  1995-02-10     802.66
# 29  1995-02-13     805.40

# %%
# has_null = selected_data.isnull().values.any()
# print(has_null)
# Out:
# False

# %%
ex_data = selected_data.copy()
# 완료된 데이터 ex_data

# %% [markdown]
# # 전국 학원 정보 가져와서 합치기 (시군구 단위)

# %%
academy_data = pd.read_csv("./data/학원교습소정보_2024년08월31일기준.csv",encoding='cp949')
# Out:
# C:\Users\5-12\AppData\Local\Temp\ipykernel_13224\873938545.py:1: DtypeWarning: Columns (6,22) have mixed types. Specify dtype option on import or set low_memory=False.
#   academy_data = pd.read_csv("./data/학원교습소정보_2024년08월31일기준.csv",encoding='cp949')

# %%
academy_data
# Out:
#        시도교육청코드      시도교육청명 행정구역명 학원교습소구분명      학원지정번호                     학원명  \
# 0          B10    서울특별시교육청   강남구       학원  3000040160                    대치학원
# 1          B10    서울특별시교육청   강남구       학원  3000039285      (A STUDIO)에이스튜디오학원
# 2          B10    서울특별시교육청   강남구       학원        2531            (주)멘토르수학전문학원
# 3          B10    서울특별시교육청   강남구       학원  3000012704     (주)산에듀김영준국어논술전문별관학원
# 4          B10    서울특별시교육청   강남구       학원  3000043003  (주)산에듀김영준국어논술전문프리미엄관학원
# ...        ...         ...   ...      ...         ...                     ...
# 136611     T10  제주특별자치도교육청   제주시      교습소        3699              화가처럼그리기교습소
# 136612     T10  제주특별자치도교육청   제주시       학원        1478                    화랑학원
# 136613     T10  제주특별자치도교육청   제주시      교습소  3000011860                화북필수학교습소
# 136614     T10  제주특별자치도교육청   제주시      교습소  3000011504                 화원미술교습소
# 136615     T10  제주특별자치도교육청   제주시       학원  3000011719               흙빚는화가미술학원
#
#             개설일자      등록일자 등록상태명    휴원시작일자  ...      교습과정목록명           교습과정명  \
# 0       20211111  20211111    개원            ...        보습·논술           보습·논술
# 1       20210630  20210630    개원            ...          NaN  연기(연극,뮤지컬,오페라)
# 2       19950804  19950804    개원            ...          보습,              보습
# 3       20110415  20110415    개원            ...        보습·논술           보습·논술
# 4       20221230  20221230    개원            ...        보습·논술           보습·논술
# ...          ...       ...   ...       ...  ...          ...             ...
# 136611  20050223  20050223    개원            ...    미술(월600분)              미술
# 136612  19970307  19970307    개원            ...          보습,              보습
# 136613  20200313  20200313    개원            ...        초등수학1              보습
# 136614  20181001  20180904    개원            ...  미술(일반,720분)              미술
# 136615  20190916  20190826    개원            ...          미술,              미술
#
#                                                   인당수강료내용 수강료공개여부 기숙사학원여부  \
# 0                                                               Y       N
# 1                                                               Y       N
# 2                                                               N       N
# 3                                                               N       N
# 4                                                               Y       N
# ...                                                   ...     ...     ...
# 136611                                                          N       N
# 136612                                                          Y       N
# 136613  초등수학1:100000, 초등수학2:130000, 중등수학1:150000, 중등수학...       Y       N
# 136614  미술(일반,720분):90000, 미술(일반, 840분):100000, 미술(일반,...       Y       N
# 136615                                                          Y       N
#
#                       시설도로명주소                시설도로명상세주소 시설도로명우편번호  \
# 0           서울특별시 강남구 삼성로 347       , 201호 (대치동, 대일빌딩)      6202
# 1         서울특별시 강남구 논현로134길 5           , 5층, 6층 (논현동)      6052
# 2        서울특별시 강남구 남부순환로 2927  , 501호 일부(대치동, 대치 클래시아)      6280
# 3         서울특별시 강남구 선릉로62길 27             , 1~4층 (대치동)    135998
# 4       서울특별시 강남구 선릉로62길 32-2         , 5층 (대치동, 대아빌딩)      6207
# ...                       ...                      ...       ...
# 136611  제주특별자치도 제주시 서광로20길 26                 , (도남동)      63201
# 136612    제주특별자치도 제주시 중앙로 521              , 3층 (아라일동)     63247
# 136613   제주특별자치도 제주시 진남로4길 19              , 1층 (화북일동)     63291
# 136614     제주특별자치도 제주시 인다9길 9              , 1층 (아라일동)     63247
# 136615    제주특별자치도 제주시 아란5길 13            , 201호 (아라일동)     63237
#
#                 전화번호      수정일자
# 0       02-2135-7135  20240908
# 1       02-6013-8112  20231018
# 2        02-564-5002  20240428
# 3        02-501-0575  20240908
# 4                NaN  20240908
# ...              ...       ...
# 136611  064-758-3006  20231018
# 136612  064-758-4722  20240825
# 136613           NaN  20240512
# 136614           NaN  20231018
# 136615  064-758-0365  20231018
#
# [136616 rows x 25 columns]

# %%
academy_data.columns
# Out:
# Index(['시도교육청코드', '시도교육청명', '행정구역명', '학원교습소구분명', '학원지정번호', '학원명', '개설일자',
#        '등록일자', '등록상태명', '휴원시작일자', '휴원종료일자', '정원합계', '일시수용능력인원합계', '분야명',
#        '교습계열명', '교습과정목록명', '교습과정명', '인당수강료내용', '수강료공개여부', '기숙사학원여부', '시설도로명주소',
#        '시설도로명상세주소', '시설도로명우편번호', '전화번호', '수정일자'],
#       dtype='object')

# %%
academy_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 136616 entries, 0 to 136615
# Data columns (total 25 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   시도교육청코드     136616 non-null  object
#  1   시도교육청명      136616 non-null  object
#  2   행정구역명       136474 non-null  object
#  3   학원교습소구분명    136616 non-null  object
#  4   학원지정번호      136616 non-null  int64
#  5   학원명         136616 non-null  object
#  6   개설일자        136616 non-null  object
#  7   등록일자        136616 non-null  int64
#  8   등록상태명       136616 non-null  object
#  9   휴원시작일자      136616 non-null  object
#  10  휴원종료일자      136616 non-null  object
#  11  정원합계        136616 non-null  int64
#  12  일시수용능력인원합계  136616 non-null  int64
#  13  분야명         136612 non-null  object
#  14  교습계열명       119566 non-null  object
#  15  교습과정목록명     99036 non-null   object
#  16  교습과정명       119591 non-null  object
#  17  인당수강료내용     136616 non-null  object
#  18  수강료공개여부     136616 non-null  object
#  19  기숙사학원여부     136616 non-null  object
#  20  시설도로명주소     136616 non-null  object
#  21  시설도로명상세주소   136616 non-null  object
#  22  시설도로명우편번호   136616 non-null  object
#  23  전화번호        82074 non-null   object
#  24  수정일자        136616 non-null  int64
# dtypes: int64(5), object(20)
# memory usage: 26.1+ MB

# %%
academy_data['시도교육청명'].unique()
# Out:
# array(['서울특별시교육청', '부산광역시교육청', '대구광역시교육청', '인천광역시교육청', '광주광역시교육청',
#        '대전광역시교육청', '울산광역시교육청', '세종특별자치시교육청', '경기도교육청', '강원특별자치도교육청',
#        '충청북도교육청', '충청남도교육청', '전북특별자치도교육청', '전라북도교육청', '전라남도교육청',
#        '경상북도교육청', '경상남도교육청', '제주특별자치도교육청'], dtype=object)

# %%
sorted_academy_data = academy_data.sort_values(by='시도교육청명')

# %%
sorted_academy_data.columns
# Out:
# Index(['시도교육청코드', '시도교육청명', '행정구역명', '학원교습소구분명', '학원지정번호', '학원명', '개설일자',
#        '등록일자', '등록상태명', '휴원시작일자', '휴원종료일자', '정원합계', '일시수용능력인원합계', '분야명',
#        '교습계열명', '교습과정목록명', '교습과정명', '인당수강료내용', '수강료공개여부', '기숙사학원여부', '시설도로명주소',
#        '시설도로명상세주소', '시설도로명우편번호', '전화번호', '수정일자'],
#       dtype='object')

# %%
sorted_academy_data.head()
# Out:
#        시도교육청코드      시도교육청명 행정구역명 학원교습소구분명      학원지정번호              학원명  \
# 102594     K10  강원특별자치도교육청   원주시       학원  3000013200        브릴리언트댄스학원
# 103185     K10  강원특별자치도교육청   원주시       학원  3000013459        한양피아노음악학원
# 103186     K10  강원특별자치도교육청   원주시       학원  3000010730          한예종무용학원
# 103187     K10  강원특별자치도교육청   원주시      교습소  3000012686  한우리독서토론논술 단계교습소
# 103188     K10  강원특별자치도교육청   원주시      교습소  3000016368   한우리독서토론논술반곡교습소
#
#             개설일자      등록일자 등록상태명    휴원시작일자  ... 교습과정목록명  교습과정명  \
# 102594  20190826  20190826    개원            ...     댄스,    NaN
# 103185  20200601  20200525    개원            ...     NaN     음악
# 103186  20091205  20091204    개원            ...     무용,     무용
# 103187  20180206  20180206    개원            ...  중등문법특강     보습
# 103188  20230911  20230911    개원            ...     NaN    NaN
#
#                                                   인당수강료내용 수강료공개여부 기숙사학원여부  \
# 102594                                                          Y       N
# 103185                                                          Y       N
# 103186                                                          Y       N
# 103187  중등문법특강:40000, 초등논술:150000, 중등논술:160000, 중등교과문학...       Y       N
# 103188                                                          Y
#
#                        시설도로명주소        시설도로명상세주소 시설도로명우편번호          전화번호  \
# 102594      강원특별자치도 원주시 양지로 80     3층 209호(반곡동)     26462           NaN
# 103185  강원특별자치도 원주시 현충로58번길 44          3층(태장동)     26325  033-742-8615
# 103186      강원특별자치도 원주시 반곡길 62          3층(반곡동)     26457  033-764-1431
# 103187      강원특별자치도 원주시 봉화로 76  (단계동), 상가동 207호     26420           NaN
# 103188   강원특별자치도 원주시 오리현길 62-2   119동 106호(반곡동)     26457           NaN
#
#             수정일자
# 102594  20231018
# 103185  20240310
# 103186  20240121
# 103187  20240721
# 103188  20231018
#
# [5 rows x 25 columns]

# %%
academy_data_index = list(academy_data['시도교육청명'].unique())
academy_data_index
# Out:
# ['서울특별시교육청',
#  '부산광역시교육청',
#  '대구광역시교육청',
#  '인천광역시교육청',
#  '광주광역시교육청',
#  '대전광역시교육청',
#  '울산광역시교육청',
#  '세종특별자치시교육청',
#  '경기도교육청',
#  '강원특별자치도교육청',
#  '충청북도교육청',
#  '충청남도교육청',
#  '전북특별자치도교육청',
#  '전라북도교육청',
#  '전라남도교육청',
#  '경상북도교육청',
#  '경상남도교육청',
#  '제주특별자치도교육청']

# %% [markdown]
# 1. 아파트 '시군구' 기준 ㅇㅇ 도 ㅇㅇ시를 뽑고
# 2. 학원 데이터의 '시도교육청명'과 '행정구역명'의 ㅇㅇ도 ㅇㅇ 시군구를 뽑아서 비교
